# %% [markdown]
# # Extract 5000 first rows from trip & status databases

# %%
import pandas as pd

# קריאה רק של 5000 השורות הראשונות מכל קובץ
status_sample = pd.read_csv(
    r'C:\Users\aviyaoh\Downloads\csv_and_merge_files\Populus Data\2023-04_Status.csv',
    nrows=5000
)

trips_sample = pd.read_csv(
    r'C:\Users\aviyaoh\Downloads\csv_and_merge_files\Populus Data\2023-04_Trips.csv',
    nrows=5000
)

# שמירה לקבצי CSV חדשים
status_sample.to_csv(
    r'C:\Users\aviyaoh\Downloads\csv_and_merge_files\Populus Data\2023-04_Status_5000rows.csv',
    index=False
)

trips_sample.to_csv(
    r'C:\Users\aviyaoh\Downloads\csv_and_merge_files\Populus Data\2023-04_Trips_5000rows.csv',
    index=False
)
